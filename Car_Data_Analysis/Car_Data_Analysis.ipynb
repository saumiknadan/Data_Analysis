# %% [markdown]
# <a href="https://colab.research.google.com/github/saumiknadan/DataScience/blob/main/project_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
car = pd.read_csv(r'/content/drive/MyDrive/Colab_Notebooks/Basic_Data_Science/Cars_Data.csv')   # r is for solving unicode error

# %%
car.head(2)
# Out:
#     Make           Model   Type Origin  ... MPG_Highway  Weight Wheelbase  Length
# 0  Acura             MDX    SUV   Asia  ...        23.0  4451.0     106.0   189.0
# 1  Acura  RSX Type S 2dr  Sedan   Asia  ...        31.0  2778.0     101.0   172.0
#
# [2 rows x 15 columns]

# %%
car.shape
# Out:
# (432, 15)

# %% [markdown]
# **Find All NULL value. If there is any null value then fill it with the mean values of that column.**

# %%
car.isnull()
# Out:
#       Make  Model   Type  Origin  ...  MPG_Highway  Weight  Wheelbase  Length
# 0    False  False  False   False  ...        False   False      False   False
# 1    False  False  False   False  ...        False   False      False   False
# 2    False  False  False   False  ...        False   False      False   False
# 3    False  False  False   False  ...        False   False      False   False
# 4    False  False  False   False  ...        False   False      False   False
# ..     ...    ...    ...     ...  ...          ...     ...        ...     ...
# 427  False  False  False   False  ...        False   False      False   False
# 428  False  False  False   False  ...        False   False      False   False
# 429  False  False  False   False  ...        False   False      False   False
# 430  False  False  False   False  ...        False   False      False   False
# 431  False  False  False   False  ...        False   False      False   False
#
# [432 rows x 15 columns]

# %%
car.isnull().sum()
# Out:
# Make           4
# Model          4
# Type           4
# Origin         4
# DriveTrain     4
# MSRP           4
# Invoice        4
# EngineSize     4
# Cylinders      6
# Horsepower     4
# MPG_City       4
# MPG_Highway    4
# Weight         4
# Wheelbase      4
# Length         4
# dtype: int64

# %% [markdown]
# > data['#Col_name'].fillna['#value']   eta dile null value gulo ekta value diye replace hoye jabe....

# %%
car['Cylinders'].fillna(car['Cylinders'].mean())    # replace null value with mean

# %%
car['Cylinders'].fillna(car['Cylinders'].mean(), inplace=True)  # inplace command data er change ta permanent kore

# %%
car.isnull().sum()
# Out:
# Make           4
# Model          4
# Type           4
# Origin         4
# DriveTrain     4
# MSRP           4
# Invoice        4
# EngineSize     4
# Cylinders      0
# Horsepower     4
# MPG_City       4
# MPG_Highway    4
# Weight         4
# Wheelbase      4
# Length         4
# dtype: int64

# %% [markdown]
# **2) Based on value count**
#
#
# *   Check what are the different types of Make are there in our dataset, And what is the count (occurence) of each Make in the data?

# %%
car.head(2)
# Out:
#     Make           Model   Type Origin  ... MPG_Highway  Weight Wheelbase  Length
# 0  Acura             MDX    SUV   Asia  ...        23.0  4451.0     106.0   189.0
# 1  Acura  RSX Type S 2dr  Sedan   Asia  ...        31.0  2778.0     101.0   172.0
#
# [2 rows x 15 columns]

# %%
car['Make'].unique()
# Out:
# array(['Acura', 'Audi', 'BMW', nan, 'Buick', 'Cadillac', 'Chevrolet',
#        'Chrysler', 'Dodge', 'Ford', 'GMC', 'Honda', 'Hummer', 'Hyundai',
#        'Infiniti', 'Isuzu', 'Jaguar', 'Jeep', 'Kia', 'Land Rover',
#        'Lexus', 'Lincoln', 'MINI', 'Mazda', 'Mercedes-Benz', 'Mercury',
#        'Mitsubishi', 'Nissan', 'Oldsmobile', 'Pontiac', 'Porsche', 'Saab',
#        'Saturn', 'Scion', 'Subaru', 'Suzuki', 'Toyota', 'Volkswagen',
#        'Volvo'], dtype=object)

# %%
car['Make'].value_counts()
# Out:
# Toyota           28
# Chevrolet        27
# Mercedes-Benz    26
# Ford             23
# BMW              20
# Audi             19
# Honda            17
# Nissan           17
# Volkswagen       15
# Chrysler         15
# Mitsubishi       13
# Dodge            13
# Jaguar           12
# Hyundai          12
# Volvo            12
# Mazda            11
# Kia              11
# Lexus            11
# Subaru           11
# Pontiac          11
# Buick             9
# Mercury           9
# Lincoln           9
# Suzuki            8
# GMC               8
# Saturn            8
# Cadillac          8
# Infiniti          8
# Acura             7
# Porsche           7
# Saab              7
# Jeep              3
# Oldsmobile        3
# Land Rover        3
# Isuzu             2
# MINI              2
# Scion             2
# Hummer            1
# Name: Make, dtype: int64

# %% [markdown]
# **3) Filtering**
#
#
# *   Show all the records where origin is Asia or Europe

# %%
car.head(2)
# Out:
#     Make           Model   Type Origin  ... MPG_Highway  Weight Wheelbase  Length
# 0  Acura             MDX    SUV   Asia  ...        23.0  4451.0     106.0   189.0
# 1  Acura  RSX Type S 2dr  Sedan   Asia  ...        31.0  2778.0     101.0   172.0
#
# [2 rows x 15 columns]

# %%
car[(car['Origin']=="Asia") | (car['Origin']=="Europe")]
# Out:
#       Make                    Model   Type  ...  Weight Wheelbase Length
# 0    Acura                      MDX    SUV  ...  4451.0     106.0  189.0
# 1    Acura           RSX Type S 2dr  Sedan  ...  2778.0     101.0  172.0
# 2    Acura                  TSX 4dr  Sedan  ...  3230.0     105.0  183.0
# 3    Acura                   TL 4dr  Sedan  ...  3575.0     108.0  186.0
# 4    Acura               3.5 RL 4dr  Sedan  ...  3880.0     115.0  197.0
# ..     ...                      ...    ...  ...     ...       ...    ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  ...  3450.0     105.0  186.0
# 428  Volvo  C70 HPT convertible 2dr  Sedan  ...  3450.0     105.0  186.0
# 429  Volvo               S80 T6 4dr  Sedan  ...  3653.0     110.0  190.0
# 430  Volvo                      V40  Wagon  ...  2822.0     101.0  180.0
# 431  Volvo                     XC70  Wagon  ...  3823.0     109.0  186.0
#
# [281 rows x 15 columns]

# %%
car[car['Origin'].isin(['Asia','Europe'])]
# Out:
#       Make                    Model   Type  ...  Weight Wheelbase Length
# 0    Acura                      MDX    SUV  ...  4451.0     106.0  189.0
# 1    Acura           RSX Type S 2dr  Sedan  ...  2778.0     101.0  172.0
# 2    Acura                  TSX 4dr  Sedan  ...  3230.0     105.0  183.0
# 3    Acura                   TL 4dr  Sedan  ...  3575.0     108.0  186.0
# 4    Acura               3.5 RL 4dr  Sedan  ...  3880.0     115.0  197.0
# ..     ...                      ...    ...  ...     ...       ...    ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  ...  3450.0     105.0  186.0
# 428  Volvo  C70 HPT convertible 2dr  Sedan  ...  3450.0     105.0  186.0
# 429  Volvo               S80 T6 4dr  Sedan  ...  3653.0     110.0  190.0
# 430  Volvo                      V40  Wagon  ...  2822.0     101.0  180.0
# 431  Volvo                     XC70  Wagon  ...  3823.0     109.0  186.0
#
# [281 rows x 15 columns]

# %% [markdown]
# **4) Remove Unwanted records**
#
#
# *   Remove all the records where Weight is above 4000

# %%
car.head(2)
# Out:
#     Make           Model   Type Origin  ... MPG_Highway  Weight Wheelbase  Length
# 0  Acura             MDX    SUV   Asia  ...        23.0  4451.0     106.0   189.0
# 1  Acura  RSX Type S 2dr  Sedan   Asia  ...        31.0  2778.0     101.0   172.0
#
# [2 rows x 15 columns]

# %%
car[car['Weight']>4000]
# Out:
#            Make                           Model  ... Wheelbase Length
# 0         Acura                             MDX  ...     106.0  189.0
# 15         Audi  A4 3.0 Quattro convertible 2dr  ...     105.0  180.0
# 17         Audi              A6 4.2 Quattro 4dr  ...     109.0  193.0
# 18         Audi                A8 L Quattro 4dr  ...     121.0  204.0
# 20         Audi                        RS 6 4dr  ...     109.0  191.0
# ..          ...                             ...  ...       ...    ...
# 405  Volkswagen                      Touareg V6  ...     112.0  187.0
# 415  Volkswagen                     Phaeton 4dr  ...     118.0  204.0
# 416  Volkswagen                 Phaeton W12 4dr  ...     118.0  204.0
# 419  Volkswagen                       Passat W8  ...     106.0  184.0
# 420       Volvo                         XC90 T6  ...     113.0  189.0
#
# [103 rows x 15 columns]

# %%
car[~(car['Weight']>4000)]         # ~ is used for removing the data for satisfying condition
# Out:
#       Make                    Model   Type  ...  Weight Wheelbase Length
# 1    Acura           RSX Type S 2dr  Sedan  ...  2778.0     101.0  172.0
# 2    Acura                  TSX 4dr  Sedan  ...  3230.0     105.0  183.0
# 3    Acura                   TL 4dr  Sedan  ...  3575.0     108.0  186.0
# 4    Acura               3.5 RL 4dr  Sedan  ...  3880.0     115.0  197.0
# 5    Acura  3.5 RL w/Navigation 4dr  Sedan  ...  3893.0     115.0  197.0
# ..     ...                      ...    ...  ...     ...       ...    ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  ...  3450.0     105.0  186.0
# 428  Volvo  C70 HPT convertible 2dr  Sedan  ...  3450.0     105.0  186.0
# 429  Volvo               S80 T6 4dr  Sedan  ...  3653.0     110.0  190.0
# 430  Volvo                      V40  Wagon  ...  2822.0     101.0  180.0
# 431  Volvo                     XC70  Wagon  ...  3823.0     109.0  186.0
#
# [329 rows x 15 columns]

# %% [markdown]
# **5) Apply function on a column**
#
#
# *   Increase all the values of "MPF_City" column by 3

# %%
car.head(2)
# Out:
#     Make           Model   Type Origin  ... MPG_Highway  Weight Wheelbase  Length
# 0  Acura             MDX    SUV   Asia  ...        23.0  4451.0     106.0   189.0
# 1  Acura  RSX Type S 2dr  Sedan   Asia  ...        31.0  2778.0     101.0   172.0
#
# [2 rows x 15 columns]

# %%
car['MPG_City'] = car['MPG_City'].apply(lambda x:x+3)

# %%
car
# Out:
#       Make                    Model   Type  ...  Weight Wheelbase Length
# 0    Acura                      MDX    SUV  ...  4451.0     106.0  189.0
# 1    Acura           RSX Type S 2dr  Sedan  ...  2778.0     101.0  172.0
# 2    Acura                  TSX 4dr  Sedan  ...  3230.0     105.0  183.0
# 3    Acura                   TL 4dr  Sedan  ...  3575.0     108.0  186.0
# 4    Acura               3.5 RL 4dr  Sedan  ...  3880.0     115.0  197.0
# ..     ...                      ...    ...  ...     ...       ...    ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  ...  3450.0     105.0  186.0
# 428  Volvo  C70 HPT convertible 2dr  Sedan  ...  3450.0     105.0  186.0
# 429  Volvo               S80 T6 4dr  Sedan  ...  3653.0     110.0  190.0
# 430  Volvo                      V40  Wagon  ...  2822.0     101.0  180.0
# 431  Volvo                     XC70  Wagon  ...  3823.0     109.0  186.0
#
# [432 rows x 15 columns]
