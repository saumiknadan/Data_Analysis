# %% [markdown]
# <a href="https://colab.research.google.com/github/saumiknadan/DataScience/blob/main/project_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Weather Data analysis.**

# %%
import pandas as pd

# %%
data = pd.read_csv("/content/drive/MyDrive/Colab_Notebooks/Basic_Data_Science/Weather_Data.csv")

# %%
data
# Out:
#              Date/Time  Temp_C  ...  Press_kPa               Weather
# 0        1/1/2012 0:00    -1.8  ...     101.24                   Fog
# 1        1/1/2012 1:00    -1.8  ...     101.24                   Fog
# 2        1/1/2012 2:00    -1.8  ...     101.26  Freezing Drizzle,Fog
# 3        1/1/2012 3:00    -1.5  ...     101.27  Freezing Drizzle,Fog
# 4        1/1/2012 4:00    -1.5  ...     101.23                   Fog
# ...                ...     ...  ...        ...                   ...
# 8779  12/31/2012 19:00     0.1  ...     100.13                  Snow
# 8780  12/31/2012 20:00     0.2  ...     100.03                  Snow
# 8781  12/31/2012 21:00    -0.5  ...      99.95                  Snow
# 8782  12/31/2012 22:00    -0.2  ...      99.91                  Snow
# 8783  12/31/2012 23:00     0.0  ...      99.89                  Snow
#
# [8784 rows x 8 columns]

# %%
data.head(5)
# Out:
#        Date/Time  Temp_C  ...  Press_kPa               Weather
# 0  1/1/2012 0:00    -1.8  ...     101.24                   Fog
# 1  1/1/2012 1:00    -1.8  ...     101.24                   Fog
# 2  1/1/2012 2:00    -1.8  ...     101.26  Freezing Drizzle,Fog
# 3  1/1/2012 3:00    -1.5  ...     101.27  Freezing Drizzle,Fog
# 4  1/1/2012 4:00    -1.5  ...     101.23                   Fog
#
# [5 rows x 8 columns]

# %%
data.shape
# Out:
# (8784, 8)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=8784, step=1)

# %%
data.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %%
data['Weather'].unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %%
data['Weather'].nunique()
# Out:
# 50

# %%
data.nunique()
# Out:
# Date/Time           8784
# Temp_C               533
# Dew Point Temp_C     489
# Rel Hum_%             83
# Wind Speed_km/h       34
# Visibility_km         24
# Press_kPa            518
# Weather               50
# dtype: int64

# %%
data.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-29a79790751a> in <module>()
# ----> 1 data.unique()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5139             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5140                 return self[name]
# -> 5141             return object.__getattribute__(self, name)
#    5142
#    5143     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
data.count()        # total number of non-null values
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %%
data['Weather'].value_counts()       #protita unique value kotobar appear hoyeche seta dekhabe
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %% [markdown]
# > **Unique Wind speed**

# %%
data.head()
# Out:
#        Date/Time  Temp_C  ...  Press_kPa               Weather
# 0  1/1/2012 0:00    -1.8  ...     101.24                   Fog
# 1  1/1/2012 1:00    -1.8  ...     101.24                   Fog
# 2  1/1/2012 2:00    -1.8  ...     101.26  Freezing Drizzle,Fog
# 3  1/1/2012 3:00    -1.5  ...     101.27  Freezing Drizzle,Fog
# 4  1/1/2012 4:00    -1.5  ...     101.23                   Fog
#
# [5 rows x 8 columns]

# %%
data['Wind Speed_km/h'].unique()
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2])

# %%
data['Wind Speed_km/h'].nunique()
# Out:
# 34

# %%
len(data['Wind Speed_km/h'].unique())
# Out:
# 34

# %%
That means amader wind speed er unique value thik ache.
***********************************

# %% [markdown]
# > **2) Find the number of times when the 'Weather is exactly Clear'.**

# %%
data.head()
# Out:
#        Date/Time  Temp_C  ...  Press_kPa               Weather
# 0  1/1/2012 0:00    -1.8  ...     101.24                   Fog
# 1  1/1/2012 1:00    -1.8  ...     101.24                   Fog
# 2  1/1/2012 2:00    -1.8  ...     101.26  Freezing Drizzle,Fog
# 3  1/1/2012 3:00    -1.5  ...     101.27  Freezing Drizzle,Fog
# 4  1/1/2012 4:00    -1.5  ...     101.23                   Fog
#
# [5 rows x 8 columns]

# %%
#Value count

data['Weather'].value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
# Filtering process
data['Weather']== 'Clear'                # Weather = Clear kina check kore output dekhacche
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8779    False
# 8780    False
# 8781    False
# 8782    False
# 8783    False
# Name: Weather, Length: 8784, dtype: bool

# %%
data.Weather== 'Clear'                  # Weather = Clear kina check kore output dekhacche
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8779    False
# 8780    False
# 8781    False
# 8782    False
# 8783    False
# Name: Weather, Length: 8784, dtype: bool

# %%
# data[data['Weather']== 'Clear']  same kaj korbe

data[data.Weather== 'Clear']        # Weather = Clear er record gulo show korbe.. 1326 ta record show koreche... mane 1326 ti record e weather clear..
# Out:
#              Date/Time  Temp_C  ...  Press_kPa  Weather
# 67      1/3/2012 19:00   -16.9  ...     101.74    Clear
# 114     1/5/2012 18:00    -7.1  ...     100.71    Clear
# 115     1/5/2012 19:00    -9.2  ...     100.80    Clear
# 116     1/5/2012 20:00    -9.8  ...     100.83    Clear
# 117     1/5/2012 21:00    -9.0  ...     100.83    Clear
# ...                ...     ...  ...        ...      ...
# 8646   12/26/2012 6:00   -13.4  ...     102.47    Clear
# 8698  12/28/2012 10:00    -6.1  ...     101.27    Clear
# 8713   12/29/2012 1:00   -11.9  ...     101.31    Clear
# 8714   12/29/2012 2:00   -11.8  ...     101.33    Clear
# 8756  12/30/2012 20:00   -13.8  ...     101.52    Clear
#
# [1326 rows x 8 columns]

# %%
# Get groupby method

data.groupby('Weather').get_group('Clear')        # Weather = Clear er record gulo show korbe..1326 ta record show koreche... mane 1326 ti record e weather clear..
# Out:
#              Date/Time  Temp_C  ...  Press_kPa  Weather
# 67      1/3/2012 19:00   -16.9  ...     101.74    Clear
# 114     1/5/2012 18:00    -7.1  ...     100.71    Clear
# 115     1/5/2012 19:00    -9.2  ...     100.80    Clear
# 116     1/5/2012 20:00    -9.8  ...     100.83    Clear
# 117     1/5/2012 21:00    -9.0  ...     100.83    Clear
# ...                ...     ...  ...        ...      ...
# 8646   12/26/2012 6:00   -13.4  ...     102.47    Clear
# 8698  12/28/2012 10:00    -6.1  ...     101.27    Clear
# 8713   12/29/2012 1:00   -11.9  ...     101.31    Clear
# 8714   12/29/2012 2:00   -11.8  ...     101.33    Clear
# 8756  12/30/2012 20:00   -13.8  ...     101.52    Clear
#
# [1326 rows x 8 columns]

# %% [markdown]
# > **3) Find the number of times when the 'Wind Speed was exactly 4 km/h'.**

# %%
data.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  ...  Visibility_km  Press_kPa  Weather
# 0  1/1/2012 0:00    -1.8              -3.9  ...            8.0     101.24      Fog
# 1  1/1/2012 1:00    -1.8              -3.7  ...            8.0     101.24      Fog
#
# [2 rows x 8 columns]

# %%
#get group method
data.groupby('Wind Speed_km/h').get_group(4)       #Ans
# Out:
#              Date/Time  Temp_C  ...  Press_kPa       Weather
# 0        1/1/2012 0:00    -1.8  ...     101.24           Fog
# 1        1/1/2012 1:00    -1.8  ...     101.24           Fog
# 96       1/5/2012 0:00    -8.8  ...     100.32          Snow
# 101      1/5/2012 5:00    -7.0  ...     100.19          Snow
# 146      1/7/2012 2:00    -8.1  ...     100.15        Cloudy
# ...                ...     ...  ...        ...           ...
# 8768   12/31/2012 8:00    -8.6  ...     101.14  Snow Showers
# 8769   12/31/2012 9:00    -8.1  ...     101.09          Snow
# 8770  12/31/2012 10:00    -7.4  ...     101.05      Snow,Fog
# 8772  12/31/2012 12:00    -5.8  ...     100.78          Snow
# 8773  12/31/2012 13:00    -4.6  ...     100.63          Snow
#
# [474 rows x 8 columns]

# %%
#data[data.Wind Speed_km/h == 4]   space er jnno kaj korbe na
#bool method

data[data['Wind Speed_km/h'] == 4]               #ans
# Out:
#              Date/Time  Temp_C  ...  Press_kPa       Weather
# 0        1/1/2012 0:00    -1.8  ...     101.24           Fog
# 1        1/1/2012 1:00    -1.8  ...     101.24           Fog
# 96       1/5/2012 0:00    -8.8  ...     100.32          Snow
# 101      1/5/2012 5:00    -7.0  ...     100.19          Snow
# 146      1/7/2012 2:00    -8.1  ...     100.15        Cloudy
# ...                ...     ...  ...        ...           ...
# 8768   12/31/2012 8:00    -8.6  ...     101.14  Snow Showers
# 8769   12/31/2012 9:00    -8.1  ...     101.09          Snow
# 8770  12/31/2012 10:00    -7.4  ...     101.05      Snow,Fog
# 8772  12/31/2012 12:00    -5.8  ...     100.78          Snow
# 8773  12/31/2012 13:00    -4.6  ...     100.63          Snow
#
# [474 rows x 8 columns]

# %% [markdown]
# > **4) Find Out the NULL values in the data.**

# %%
data.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  ...  Visibility_km  Press_kPa  Weather
# 0  1/1/2012 0:00    -1.8              -3.9  ...            8.0     101.24      Fog
# 1  1/1/2012 1:00    -1.8              -3.7  ...            8.0     101.24      Fog
#
# [2 rows x 8 columns]

# %%
data.isnull()
# Out:
#       Date/Time  Temp_C  Dew Point Temp_C  ...  Visibility_km  Press_kPa  Weather
# 0         False   False             False  ...          False      False    False
# 1         False   False             False  ...          False      False    False
# 2         False   False             False  ...          False      False    False
# 3         False   False             False  ...          False      False    False
# 4         False   False             False  ...          False      False    False
# ...         ...     ...               ...  ...            ...        ...      ...
# 8779      False   False             False  ...          False      False    False
# 8780      False   False             False  ...          False      False    False
# 8781      False   False             False  ...          False      False    False
# 8782      False   False             False  ...          False      False    False
# ...

# %%
data.isnull().sum()             #no null values
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %% [markdown]
# > **5) Rename the column name 'Weather' of the dataframe to 'Weather Condition'.**

# %%
data.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  ...  Visibility_km  Press_kPa  Weather
# 0  1/1/2012 0:00    -1.8              -3.9  ...            8.0     101.24      Fog
# 1  1/1/2012 1:00    -1.8              -3.7  ...            8.0     101.24      Fog
#
# [2 rows x 8 columns]

# %%
data.rename(columns={'Weather' : 'Weather Condition'})
# Out:
#              Date/Time  Temp_C  ...  Press_kPa     Weather Condition
# 0        1/1/2012 0:00    -1.8  ...     101.24                   Fog
# 1        1/1/2012 1:00    -1.8  ...     101.24                   Fog
# 2        1/1/2012 2:00    -1.8  ...     101.26  Freezing Drizzle,Fog
# 3        1/1/2012 3:00    -1.5  ...     101.27  Freezing Drizzle,Fog
# 4        1/1/2012 4:00    -1.5  ...     101.23                   Fog
# ...                ...     ...  ...        ...                   ...
# 8779  12/31/2012 19:00     0.1  ...     100.13                  Snow
# 8780  12/31/2012 20:00     0.2  ...     100.03                  Snow
# 8781  12/31/2012 21:00    -0.5  ...      99.95                  Snow
# 8782  12/31/2012 22:00    -0.2  ...      99.91                  Snow
# 8783  12/31/2012 23:00     0.0  ...      99.89                  Snow
#
# [8784 rows x 8 columns]

# %%
data.head(2)           #That means rename is only for temporary purpose
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  ...  Visibility_km  Press_kPa  Weather
# 0  1/1/2012 0:00    -1.8              -3.9  ...            8.0     101.24      Fog
# 1  1/1/2012 1:00    -1.8              -3.7  ...            8.0     101.24      Fog
#
# [2 rows x 8 columns]

# %%
data.rename(columns={'Weather' : 'Weather Condition'}, inplace=True)

# %%
data.head(2)     #Now it is permanent
# Out:
#        Date/Time  Temp_C  ...  Press_kPa  Weather Condition
# 0  1/1/2012 0:00    -1.8  ...     101.24                Fog
# 1  1/1/2012 1:00    -1.8  ...     101.24                Fog
#
# [2 rows x 8 columns]

# %% [markdown]
# **Mean Visibility**

# %%
data['Visibility_km'].mean()
# Out:
# 27.66444672131151

# %% [markdown]
# ** 7) What is the Standard Deviation of 'Pressure'  in this data?**

# %%
data['Press_kPa'].std()
# Out:
# 0.8440047459486474

# %% [markdown]
# ** 8) What is the Variance of 'Relative Humidity' in this data ?**

# %%
data.head(2)
# Out:
#        Date/Time  Temp_C  ...  Press_kPa  Weather Condition
# 0  1/1/2012 0:00    -1.8  ...     101.24                Fog
# 1  1/1/2012 1:00    -1.8  ...     101.24                Fog
#
# [2 rows x 8 columns]

# %%
data['Rel Hum_%'].var()      #ans
# Out:
# 286.2485501984998

# %% [markdown]
# **9) Find all instances when 'Snow' was recorded.**

# %%
data.head(2)
# Out:
#        Date/Time  Temp_C  ...  Press_kPa  Weather Condition
# 0  1/1/2012 0:00    -1.8  ...     101.24                Fog
# 1  1/1/2012 1:00    -1.8  ...     101.24                Fog
#
# [2 rows x 8 columns]

# %%
data['Weather Condition'].value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
data[data['Weather Condition'] == 'Snow']     #Not Ans... cz there are more records with snow.
# Out:
#              Date/Time  Temp_C  ...  Press_kPa  Weather Condition
# 55       1/3/2012 7:00   -14.0  ...     100.95               Snow
# 84      1/4/2012 12:00   -13.7  ...     101.25               Snow
# 86      1/4/2012 14:00   -11.3  ...     100.97               Snow
# 87      1/4/2012 15:00   -10.2  ...     100.89               Snow
# 88      1/4/2012 16:00    -9.4  ...     100.79               Snow
# ...                ...     ...  ...        ...                ...
# 8779  12/31/2012 19:00     0.1  ...     100.13               Snow
# 8780  12/31/2012 20:00     0.2  ...     100.03               Snow
# 8781  12/31/2012 21:00    -0.5  ...      99.95               Snow
# 8782  12/31/2012 22:00    -0.2  ...      99.91               Snow
# 8783  12/31/2012 23:00     0.0  ...      99.89               Snow
#
# [390 rows x 8 columns]

# %%
data[data['Weather Condition'].str.contains('Snow')]
# Out:
#              Date/Time  Temp_C  ...  Press_kPa  Weather Condition
# 41      1/2/2012 17:00    -2.1  ...      99.66       Snow Showers
# 44      1/2/2012 20:00    -5.6  ...     100.07       Snow Showers
# 45      1/2/2012 21:00    -5.8  ...     100.15       Snow Showers
# 47      1/2/2012 23:00    -7.4  ...     100.27       Snow Showers
# 48       1/3/2012 0:00    -9.0  ...     100.35       Snow Showers
# ...                ...     ...  ...        ...                ...
# 8779  12/31/2012 19:00     0.1  ...     100.13               Snow
# 8780  12/31/2012 20:00     0.2  ...     100.03               Snow
# 8781  12/31/2012 21:00    -0.5  ...      99.95               Snow
# 8782  12/31/2012 22:00    -0.2  ...      99.91               Snow
# 8783  12/31/2012 23:00     0.0  ...      99.89               Snow
#
# [583 rows x 8 columns]

# %%
data[data['Weather Condition'].str.contains('Snow')].tail(50)
# Out:
#              Date/Time  Temp_C  ...  Press_kPa      Weather Condition
# 8680  12/27/2012 16:00    -4.5  ...     100.44      Snow,Blowing Snow
# 8681  12/27/2012 17:00    -4.2  ...     100.47      Snow,Blowing Snow
# 8682  12/27/2012 18:00    -4.0  ...     100.49      Snow,Blowing Snow
# 8683  12/27/2012 19:00    -3.9  ...     100.52      Snow,Blowing Snow
# 8684  12/27/2012 20:00    -3.7  ...     100.58                   Snow
# 8685  12/27/2012 21:00    -3.7  ...     100.62  Freezing Drizzle,Snow
# 8686  12/27/2012 22:00    -3.8  ...     100.65  Freezing Drizzle,Snow
# 8687  12/27/2012 23:00    -4.0  ...     100.70                   Snow
# 8688   12/28/2012 0:00    -4.2  ...     100.78  Freezing Drizzle,Snow
# 8689   12/28/2012 1:00    -4.4  ...     100.83  Freezing Drizzle,Snow
# 8690   12/28/2012 2:00    -4.3  ...     100.93  Freezing Drizzle,Snow
# 8691   12/28/2012 3:00    -4.6  ...     101.01                   Snow
# ...

# %% [markdown]
# **10) Find all instances when 'Wind Speed is above 24' and 'Visibility is 25'.**

# %%
data.head(2)
# Out:
#        Date/Time  Temp_C  ...  Press_kPa  Weather Condition
# 0  1/1/2012 0:00    -1.8  ...     101.24                Fog
# 1  1/1/2012 1:00    -1.8  ...     101.24                Fog
#
# [2 rows x 8 columns]

# %%
data[(data['Wind Speed_km/h']>24) & (data['Visibility_km']==25)]
# Out:
#              Date/Time  Temp_C  ...  Press_kPa  Weather Condition
# 23      1/1/2012 23:00     5.3  ...      99.31             Cloudy
# 24       1/2/2012 0:00     5.2  ...      99.26       Rain Showers
# 25       1/2/2012 1:00     4.6  ...      99.26             Cloudy
# 26       1/2/2012 2:00     3.9  ...      99.26      Mostly Cloudy
# 27       1/2/2012 3:00     3.7  ...      99.30      Mostly Cloudy
# ...                ...     ...  ...        ...                ...
# 8705  12/28/2012 17:00    -8.6  ...     101.34       Mainly Clear
# 8753  12/30/2012 17:00   -12.1  ...     101.26       Mainly Clear
# 8755  12/30/2012 19:00   -13.4  ...     101.47       Mainly Clear
# 8759  12/30/2012 23:00   -12.1  ...     101.52      Mostly Cloudy
# 8760   12/31/2012 0:00   -11.1  ...     101.51             Cloudy
#
# [308 rows x 8 columns]

# %% [markdown]
# **11) What is the Mean value of each column against each 'Weather Condition ?**

# %%
data.head(2)
# Out:
#        Date/Time  Temp_C  ...  Press_kPa  Weather Condition
# 0  1/1/2012 0:00    -1.8  ...     101.24                Fog
# 1  1/1/2012 1:00    -1.8  ...     101.24                Fog
#
# [2 rows x 8 columns]

# %%
data.groupby('Weather Condition').mean()
# Out:
#                                             Temp_C  ...   Press_kPa
# Weather Condition                                   ...
# Clear                                     6.825716  ...  101.587443
# Cloudy                                    7.970544  ...  100.911441
# Drizzle                                   7.353659  ...  100.435366
# Drizzle,Fog                               8.067500  ...  100.786625
# Drizzle,Ice Pellets,Fog                   0.400000  ...  100.790000
# Drizzle,Snow                              1.050000  ...  100.890000
# Drizzle,Snow,Fog                          0.693333  ...   99.281333
# Fog                                       4.303333  ...  101.184067
# Freezing Drizzle                         -5.657143  ...  100.202857
# Freezing Drizzle,Fog                     -2.533333  ...  100.441667
# Freezing Drizzle,Haze                    -5.433333  ...  100.316667
# Freezing Drizzle,Snow                    -5.109091  ...  100.520909
# ...

# %% [markdown]
# **12) What is the Minimum & Maximum value of each column against each 'Weather Condition**

# %%
data.head(2)
# Out:
#        Date/Time  Temp_C  ...  Press_kPa  Weather Condition
# 0  1/1/2012 0:00    -1.8  ...     101.24                Fog
# 1  1/1/2012 1:00    -1.8  ...     101.24                Fog
#
# [2 rows x 8 columns]

# %%
data.groupby('Weather Condition').min()
# Out:
#                                                 Date/Time  ...  Press_kPa
# Weather Condition                                          ...
# Clear                                      1/11/2012 1:00  ...      99.52
# Cloudy                                     1/1/2012 17:00  ...      98.39
# Drizzle                                   1/23/2012 21:00  ...      97.84
# Drizzle,Fog                               1/23/2012 20:00  ...      98.65
# Drizzle,Ice Pellets,Fog                   12/17/2012 9:00  ...     100.79
# Drizzle,Snow                             12/17/2012 15:00  ...     100.63
# Drizzle,Snow,Fog                         12/18/2012 21:00  ...      97.79
# Fog                                         1/1/2012 0:00  ...      98.31
# Freezing Drizzle                          1/13/2012 10:00  ...      98.44
# Freezing Drizzle,Fog                        1/1/2012 2:00  ...      98.74
# Freezing Drizzle,Haze                      2/1/2012 11:00  ...     100.28
# ...

# %%
data.groupby('Weather Condition').max()
# Out:
#                                                 Date/Time  ...  Press_kPa
# Weather Condition                                          ...
# Clear                                       9/9/2012 5:00  ...     103.63
# Cloudy                                     9/9/2012 23:00  ...     103.65
# Drizzle                                    9/30/2012 3:00  ...     101.56
# Drizzle,Fog                                9/30/2012 2:00  ...     102.07
# Drizzle,Ice Pellets,Fog                   12/17/2012 9:00  ...     100.79
# Drizzle,Snow                             12/19/2012 18:00  ...     101.15
# Drizzle,Snow,Fog                          12/22/2012 3:00  ...     100.15
# Fog                                        9/22/2012 0:00  ...     103.04
# Freezing Drizzle                            2/1/2012 5:00  ...     101.02
# Freezing Drizzle,Fog                      12/10/2012 5:00  ...     101.27
# Freezing Drizzle,Haze                      2/1/2012 13:00  ...     100.36
# ...

# %% [markdown]
# **13) Show all the Records where Weather Condition is Fog.**

# %%
data[data['Weather Condition'] == 'Fog']
# Out:
#              Date/Time  Temp_C  ...  Press_kPa  Weather Condition
# 0        1/1/2012 0:00    -1.8  ...     101.24                Fog
# 1        1/1/2012 1:00    -1.8  ...     101.24                Fog
# 4        1/1/2012 4:00    -1.5  ...     101.23                Fog
# 5        1/1/2012 5:00    -1.4  ...     101.27                Fog
# 6        1/1/2012 6:00    -1.5  ...     101.29                Fog
# ...                ...     ...  ...        ...                ...
# 8716   12/29/2012 4:00   -16.0  ...     101.25                Fog
# 8717   12/29/2012 5:00   -14.8  ...     101.25                Fog
# 8718   12/29/2012 6:00   -13.8  ...     101.25                Fog
# 8719   12/29/2012 7:00   -14.8  ...     101.22                Fog
# 8722  12/29/2012 10:00   -12.0  ...     101.15                Fog
#
# [150 rows x 8 columns]

# %% [markdown]
# **14) Find all instances when 'Weather is Clear' and 'Visibility is above 40'.**

# %%
data[(data['Weather Condition'] == 'Clear') & (data['Visibility_km'] > 40)]
# Out:
#              Date/Time  Temp_C  ...  Press_kPa  Weather Condition
# 351    1/15/2012 15:00   -15.4  ...     102.71              Clear
# 352    1/15/2012 16:00   -15.1  ...     102.79              Clear
# 425    1/18/2012 17:00   -11.3  ...     101.54              Clear
# 440     1/19/2012 8:00   -13.7  ...     101.84              Clear
# 441     1/19/2012 9:00   -12.7  ...     101.73              Clear
# ...                ...     ...  ...        ...                ...
# 8384   12/15/2012 8:00   -10.7  ...     102.69              Clear
# 8385   12/15/2012 9:00   -10.4  ...     102.74              Clear
# 8389  12/15/2012 13:00    -8.4  ...     102.64              Clear
# 8631  12/25/2012 15:00    -7.1  ...     101.98              Clear
# 8632  12/25/2012 16:00    -7.5  ...     102.03              Clear
#
# [313 rows x 8 columns]

# %% [markdown]
# **14.1) Find all instances when 'Weather is Clear' or 'Visibility is above 40'.**

# %%
data[(data['Weather Condition'] == 'Clear') | (data['Visibility_km'] > 40)]
# Out:
#              Date/Time  Temp_C  ...  Press_kPa  Weather Condition
# 67      1/3/2012 19:00   -16.9  ...     101.74              Clear
# 106     1/5/2012 10:00    -6.0  ...     100.45       Mainly Clear
# 107     1/5/2012 11:00    -5.6  ...     100.41       Mainly Clear
# 108     1/5/2012 12:00    -4.7  ...     100.38       Mainly Clear
# 109     1/5/2012 13:00    -4.4  ...     100.40       Mainly Clear
# ...                ...     ...  ...        ...                ...
# 8749  12/30/2012 13:00   -12.4  ...     100.92      Mostly Cloudy
# 8750  12/30/2012 14:00   -11.8  ...     100.96       Mainly Clear
# 8751  12/30/2012 15:00   -11.3  ...     101.05       Mainly Clear
# 8752  12/30/2012 16:00   -11.4  ...     101.15       Mainly Clear
# 8756  12/30/2012 20:00   -13.8  ...     101.52              Clear
#
# [3027 rows x 8 columns]

# %% [markdown]
# Q. 15) Find all instances when :
# A. 'Weather is Clear' and 'Relative Humidity is greater than 50'
# or
# B. 'Visibility is above 40'

# %%
data.head(2)
# Out:
#        Date/Time  Temp_C  ...  Press_kPa  Weather Condition
# 0  1/1/2012 0:00    -1.8  ...     101.24                Fog
# 1  1/1/2012 1:00    -1.8  ...     101.24                Fog
#
# [2 rows x 8 columns]

# %%
# A ans

data[(data['Weather Condition']== 'Clear') & (data['Rel Hum_%']>50)]
# Out:
#              Date/Time  Temp_C  ...  Press_kPa  Weather Condition
# 114     1/5/2012 18:00    -7.1  ...     100.71              Clear
# 115     1/5/2012 19:00    -9.2  ...     100.80              Clear
# 116     1/5/2012 20:00    -9.8  ...     100.83              Clear
# 117     1/5/2012 21:00    -9.0  ...     100.83              Clear
# 241     1/11/2012 1:00   -10.7  ...     101.49              Clear
# ...                ...     ...  ...        ...                ...
# 8646   12/26/2012 6:00   -13.4  ...     102.47              Clear
# 8698  12/28/2012 10:00    -6.1  ...     101.27              Clear
# 8713   12/29/2012 1:00   -11.9  ...     101.31              Clear
# 8714   12/29/2012 2:00   -11.8  ...     101.33              Clear
# 8756  12/30/2012 20:00   -13.8  ...     101.52              Clear
#
# [1070 rows x 8 columns]

# %%
# A and B ans

data[((data['Weather Condition']== 'Clear') & (data['Rel Hum_%']>50)) | (data['Visibility_km']>40)]
# Out:
#              Date/Time  Temp_C  ...  Press_kPa  Weather Condition
# 106     1/5/2012 10:00    -6.0  ...     100.45       Mainly Clear
# 107     1/5/2012 11:00    -5.6  ...     100.41       Mainly Clear
# 108     1/5/2012 12:00    -4.7  ...     100.38       Mainly Clear
# 109     1/5/2012 13:00    -4.4  ...     100.40       Mainly Clear
# 110     1/5/2012 14:00    -5.1  ...     100.46       Mainly Clear
# ...                ...     ...  ...        ...                ...
# 8749  12/30/2012 13:00   -12.4  ...     100.92      Mostly Cloudy
# 8750  12/30/2012 14:00   -11.8  ...     100.96       Mainly Clear
# 8751  12/30/2012 15:00   -11.3  ...     101.05       Mainly Clear
# 8752  12/30/2012 16:00   -11.4  ...     101.15       Mainly Clear
# 8756  12/30/2012 20:00   -13.8  ...     101.52              Clear
#
# [2921 rows x 8 columns]
